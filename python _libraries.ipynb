# %%
NUMPY:
  FUNCTIONS               USES                                      EXAMPLE
1.np.array()	    Creates a NumPy array         	              a = np.array([1,2,3])
2.np.zeros()	    Creates an array filled with zeros	          np.zeros((2,3))
3.np.ones()	        Creates an array filled with ones	          np.ones((2,2))
4.np.arange()	    Creates an array with a range of values	      np.arange(1,10,2)
5.np.linspace() 	Creates evenly spaced values	              np.linspace(0,10,5)
6.np.reshape()	    Changes the shape of an array	              a.reshape(2,3)
7.np.size()	        Returns the total number of elements	      np.size(a)
8.np.shape	        Returns the shape (rows, columns)	          a.shape
9.np.ndim	        Returns the number of dimensions	          a.ndim
10.np.dtype	        Returns the data type	                      a.dtype
11.np.sum()	        Returns the sum of elements	                  np.sum(a)
12.np.mean()	    Returns the average                        	  np.mean(a)
13.np.max()  	    Returns the maximum value	                  np.max(a)
14.np.min()	        Returns the minimum value	                  np.min(a)
15.np.sort()	    Sorts the array	                              np.sort(a)

# %%
PANDAS:
  FUNCTIONS             USES                                      EXAMPLE
1.pd.Series()	      Creates a Series (1D data)	            pd.Series([10,20,30])
2.pd.DataFrame()	  Creates a DataFrame (table)	            pd.DataFrame(data)
3.pd.read_csv()  	  Reads a CSV file	                        pd.read_csv("data.csv")
4.pd.read_excel()	  Reads an Excel file	                    pd.read_excel("data.xlsx")
5.to_csv()	          Saves a DataFrame as a CSV file	        df.to_csv("data.csv")
6.head()              Displays the first 5 rows                 df.head()
7.tail()	          Displays the last 5 rows	                df.tail()
8.info()	          Shows information about the DataFrame 	df.info()
9.describe()	      Shows statistical summary             	df.describe()
10.shape	          Returns the number of rows and columns	df.shape
11.columns	          Displays column names                 	df.columns
12.drop()	          Removes rows or columns	                df.drop("Age", axis=1)
13.mean()	          Calculates the average	                df["Age"].mean()
14.max()	          Finds the maximum value               	df["Age"].max()
15.min()	          Finds the minimum value                	df["Age"].min()

# %%
MATPLOTLIB:
 FUNCTION                   USES                         EXAMPLE
1.plt.plot()	         Draws a line graph	           plt.plot(x, y)
2.plt.bar()         	 Creates a bar chart	       plt.bar(x, y)
3.plt.scatter()	         Creates a scatter plot	       plt.scatter(x, y)
4.plt.pie()	             Creates a pie chart	       plt.pie(data)
5.plt.hist()	         Creates a histogram	       plt.hist(data)
6.plt.title()	         Adds a title to the graph	   plt.title("Sales Report")
7.plt.xlabel()	         Adds a label to the X-axis	   plt.xlabel("Months")
8.plt.ylabel()	         Adds a label to the Y-axis	   plt.ylabel("Sales")
9.plt.legend()	         Displays a legend	           plt.legend()
10.plt.grid()	         Displays grid lines	       plt.grid(True)
11.plt.show()	         Displays the graph	           plt.show()
12.plt.savefig()	     Saves the graph as an image   plt.savefig("graph.png")
13.plt.xlim()	         Sets X-axis limits	           plt.xlim(0, 10)
14.plt.ylim()	         Sets Y-axis limits	           plt.ylim(0, 100)

# %%
SEABORN:
 FUNCTION                 USES                                                  EXAMPLE
1. sns.lineplot()	    Creates a line graph.	                          sns.lineplot(x=[1,2,3], y=[10,20,15])
2. sns.barplot()	    Creates a bar chart.	                          sns.barplot(x=["A","B","C"], y=[5,8,6])
3. sns.scatterplot()	Creates a scatter plot.	                          sns.scatterplot(x=[1,2,3], y=[4,5,6])
4. sns.histplot()	    Creates a histogram.                              sns.histplot([2,3,4,5,5,6])
5. sns.boxplot()	    Creates a box plot.	                              sns.boxplot(x=[10,20,30,40,100])
6. sns.violinplot()	    Creates a violin plot.	                          sns.violinplot(x=[10,20,30,40,50])
7. sns.heatmap()	    Creates a heatmap.	                              sns.heatmap([[1,2],[3,4]], annot=True)
8. sns.countplot()	    Counts category values.	                          sns.countplot(x=["A","A","B","C","B"])
9. sns.pairplot()	    Shows relationships between variables.	          sns.pairplot(sns.load_dataset("iris"))
10. sns.kdeplot()	    Creates a density curve.	                      sns.kdeplot([10,20,30,40,50])
11. sns.displot()	    Displays data distribution.	                      sns.displot([10,20,20,30,40])
12. sns.jointplot()	    Shows relationship between two variables.	      sns.jointplot(x=[1,2,3], y=[4,5,6])
13. sns.catplot()	    Creates categorical plots.	                      sns.catplot(x="day", y="total_bill", data=sns.load_dataset("tips"), kind="bar")
14. sns.regplot()	    Draws regression line.                           sns.regplot(x=[1,2,3], y=[2,4,5])
15. sns.set_style()	    Changes graph style.	                         sns.set_style("darkgrid")
